# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import geoviews as gv
import geoviews.feature as gf
import xarray as xr
from cartopy import crs
from geoviews import dim
# Out:
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.ParameterizedMetaclass: Use method 'params' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace
# WARNING:param.Dimension: Use method 'get_param_values' via param namespace

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
fp = "https://france-geojson.gregoiredavid.fr/repo/regions.geojson"
sf = gpd.read_file(fp)
sf
